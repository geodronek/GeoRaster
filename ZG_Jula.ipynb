# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r"C:\\Users\\julia\\OneDrive\\Dokumenty\\Jula\\PYTHON_NAUKA_MOJE\\GeoRaster-1\\all_schrony(XY)_csv\\all_schrony(XY)_csv.csv"

# %%
gdf = gpd.read_file(path, encoding="utf-8")

# %%
print(gdf.columns)
# Out:
# Index(['X', 'Y', 'fid', 'ObjectID', 'Rodzaj_inw', 'Możliwoś', 'Powierzchn',
#        'Pojemnoś_', 'Subiektywn', 'Rodzaj_obi', 'Przeznacze', 'Województ',
#        'Powiat', 'Adres', 'x', 'y', 'ObjectId2', 'Gmina', 'Miejscowosc'],
#       dtype='object')

# %%
print(len(gdf.loc[gdf.Powiat == 'Zielona Góra', ["ObjectID", "Powiat", "Rodzaj_obi"]]))
# Out:
# 1208

# %%
liczba_schronow_zg = len(gdf.loc[gdf.Powiat == 'Zielona Góra', ["ObjectID", "Powiat", "Rodzaj_obi"]])
print(f'Liczba schronów w powiecie Zielona Góra: {liczba_schronow_zg}')
# Out:
# Liczba schronów w powiecie Zielona Góra: 1208
